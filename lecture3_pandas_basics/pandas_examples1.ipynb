# %% [markdown]
# ### pandas-modules, basic examples

# %%
# typical imports 
# pip install numpy
# pip install pandas
import numpy as np
import pandas as pd

# %%
# will be updated during the lecture
