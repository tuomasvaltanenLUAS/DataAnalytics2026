# %% [markdown]
# ### pandas-modules, basic examples, DataFrames

# %%
# typical imports 
# pip install numpy
# pip install pandas
import numpy as np
import pandas as pd

# %%
# we can get same random values by setting 
# the random seed every time
from numpy.random import randint
np.random.seed(321)

# our rows
companies = ["Jolly Good Toys Ltd", 
             "Pristine Machines Inc.", 
             "Piggy Bank Corporation", 
             "Cars & Gears Foundation"]

# our columns
areas = ["Europe", "North_America", "South_America", "Asia", "Africa", "Other"]

# generate some sales numbers for values with NumPy

sales = randint(99999, size=(4, 6))

# combine everything into a DataFrame. Sales values are between 0 – 99999, random
df = pd.DataFrame(sales, companies, areas)

# %%
# since this is already a DataFrame, we don't need 
# to call .to_frame()
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other
# Jolly Good Toys Ltd      91537
# Pristine Machines Inc.   94536
# Piggy Bank Corporation   37389
# Cars & Gears Foundation  97335

# %% [markdown]
# **Filtering data within a DataFrame**

# %%
# if you need the data of ONE particular column only, we can filter it out:
col_df = df['Europe']

# notice, when filtering only ONE column
# the result is a pandas SERIES
col_df
# Out:
# Jolly Good Toys Ltd        97268
# Pristine Machines Inc.     24744
# Piggy Bank Corporation     28243
# Cars & Gears Foundation    57643
# Name: Europe, dtype: int32

# %%
# we usually want to filter by multiple columns
# since we usually choose the most optimal variables (columns)
# for our machine learning model for training
columns = ['North_America', 'South_America']
cols_df = df[columns]

# you can also do this in one line:
# cols_df = df[['North_America', 'South_America']]

cols_df
# Out:
#                          North_America  South_America
# Jolly Good Toys Ltd               6682           4220
# Pristine Machines Inc.           69018          99288
# Piggy Bank Corporation           44245          21633
# Cars & Gears Foundation          46518          71742

# %%
# NOTE! the column names have to match EXACTLY
# as in the original data (lowercase letters, uppercase etc.)
# handy tool to quickly check the column names:
df.columns
# Out:
# Index(['Europe', 'North_America', 'South_America', 'Asia', 'Africa', 'Other'], dtype='object')

# %% [markdown]
# **Creating new columns and fixing existing ones**

# %%
# Europe	North_America	South_America	Asia	Africa	Other
df['Total_Sales'] = df['Europe'] + df['North_America'] + df['South_America'] \
                    + df['Asia'] + df['Africa'] + df['Other']

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Pristine Machines Inc.   94536       392123
# Piggy Bank Corporation   37389       255723
# Cars & Gears Foundation  97335       421573

# %%
# THIS IS JUST A SIMULATED DEMONSTRATION TO SHOW WHY REAL DATA NEEDS OFTEN CLEANING
# basically this adds a dollar sign with this code first (we'd never do this with real data)
df['Total_Sales'] = "$ " + df['Total_Sales'].astype(str)

# %%
# notice how the Total_Sales is now text due to $ -sign
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other Total_Sales
# Jolly Good Toys Ltd      91537    $ 249443
# Pristine Machines Inc.   94536    $ 392123
# Piggy Bank Corporation   37389    $ 255723
# Cars & Gears Foundation  97335    $ 421573

# %%
# you can use this to see how Total_Sales is currently
# in object -format => text data, can't be used as is to 
# do data analytics or ML applications
# df.dtypes

# %%
# if your data has extra character in otherwise numeric columns
# we can clean it easily, e.g.
df['Total_Sales'] = df['Total_Sales'].str.replace("$ ", "").astype(int)

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Pristine Machines Inc.   94536       392123
# Piggy Bank Corporation   37389       255723
# Cars & Gears Foundation  97335       421573

# %%
# if you ever need to double-check if all columns/variables
# are surely numbers, remember NumPy's dtype
df.dtypes
# Out:
# Europe           int32
# North_America    int32
# South_America    int32
# Asia             int32
# Africa           int32
# Other            int32
# Total_Sales      int64
# dtype: object

# %%
# let's make another column based on something else
df['Monthly_Sales'] = round(df['Total_Sales'] / 12, 2)

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales  Monthly_Sales
# Jolly Good Toys Ltd      91537       249443       20786.92
# Pristine Machines Inc.   94536       392123       32676.92
# Piggy Bank Corporation   37389       255723       21310.25
# Cars & Gears Foundation  97335       421573       35131.08

# %% [markdown]
# **Deleting (dropping) unneeded columns**

# %%
# a typical pandas-notebook starts with a list of
# columns we want to immediately delete (drop)

# remember axis=1 for COLUMNS, otherwise code tries 
# to drop a row
# and we don't have a row called Monthly_Sales
df = df.drop("Monthly_Sales", axis=1)

# dropping rows is fairly rare (but possible)
# df = df.drop("Pristine Machines Inc.")

# %%
# OPTION 2:
# inplace -parameter allows us to modify a DataFrame
# WITHOUT reassigning the DataFrame back to itself
# e.g. df.drop('Monthly_Sales', axis=1, inplace=True)

# %%
# we can now see that Monthly_Sales has been 
# removed from the columns
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Pristine Machines Inc.   94536       392123
# Piggy Bank Corporation   37389       255723
# Cars & Gears Foundation  97335       421573

# %%
# you can use loc to look up a certain row in the data
# usually problematic or extreme rows in the data (outliers)
row = df.loc["Piggy Bank Corporation"]
row.to_frame()
# Out:
#                Piggy Bank Corporation
# Europe                          28243
# North_America                   44245
# South_America                   21633
# Asia                            78619
# Africa                          45594
# Other                           37389
# Total_Sales                    255723

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Pristine Machines Inc.   94536       392123
# Piggy Bank Corporation   37389       255723
# Cars & Gears Foundation  97335       421573

# %%
# use numeric index instead, notice the i in iloc
row = df.iloc[1]
row.to_frame()

# df.iloc is often used to filter a smaller part from a huge data
# for example, first 1000 rows only
# df_smaller = df.iloc[0:1000]
# Out:
#                Pristine Machines Inc.
# Europe                          24744
# North_America                   69018
# South_America                   99288
# Asia                            14068
# Africa                          90469
# Other                           94536
# Total_Sales                    392123

# %% [markdown]
# **Conditional filtering in pandas**

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Pristine Machines Inc.   94536       392123
# Piggy Bank Corporation   37389       255723
# Cars & Gears Foundation  97335       421573

# %%
# conditional filtering => remove all rows that
# are less than 300000 in total sales (or in other words
# => select those rows that exceed 300000 in total sales)

# the syntax is basically this:
# condition = df['Total_Sales'] > 300000
# filter_df = df[condition]

filter_df = df[df['Total_Sales'] > 300000]
filter_df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Pristine Machines Inc.   94536       392123
# Cars & Gears Foundation  97335       421573

# %%
# you can also have multiple conditions 

# example 1 (difficult to remember often): 
# filtered = df[(df['Europe']>30000) & (df['Asia']>20000)]

# example 2 (query is easier understand, and also used in some other optimization tasks):
# filtered = df.query("Europe > 30000 and Asia > 20000")

# RECOMMENDED: filter everything one-by-one, one condition at a time
# this is easier to remember and code "on-the-go", result is exactly same

# let's take a copy of df for this test, so we don't lose the original data 
# usually in real projects, we just override the existing dataframe
df2 = df.copy()
df2 = df2[df2['Europe'] > 50000]
df2 = df2[df2['Asia'] > 40000]
df2 = df2[df2['Other'] > 90000]

# %%
df2
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Cars & Gears Foundation  97335       421573

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales
# Jolly Good Toys Ltd      91537       249443
# Pristine Machines Inc.   94536       392123
# Piggy Bank Corporation   37389       255723
# Cars & Gears Foundation  97335       421573

# %% [markdown]
# **Using a custom function to modify/clean or add new data**

# %%
# helper function that assigns each company in the data
# a size category based on total sales
def create_sales_category(row):
    # row -parameter behaves lik a dictionary of a single row
    # in the data at a time (Series)
    total_sales = row['Total_Sales']

    # the return logic for this company
    if total_sales < 250000:
        return "Small"
    elif 250000 <= total_sales <= 350000:
        return "Medium"
    else:
        return "Large"

# %%
# create a new column with our helper function above
df['Company_Size'] = df.apply(create_sales_category, axis=1)

# %%
df
# Out:
#                          Europe  North_America  South_America   Asia  Africa  \
# Jolly Good Toys Ltd       97268           6682           4220  43807    5929
# Pristine Machines Inc.    24744          69018          99288  14068   90469
# Piggy Bank Corporation    28243          44245          21633  78619   45594
# Cars & Gears Foundation   57643          46518          71742  99722   48613
#
#                          Other  Total_Sales Company_Size
# Jolly Good Toys Ltd      91537       249443        Small
# Pristine Machines Inc.   94536       392123        Large
# Piggy Bank Corporation   37389       255723       Medium
# Cars & Gears Foundation  97335       421573        Large
