# %% [markdown]
# #### seaborn, advanced plots and features - the hue-feature

# %%
# basic imports
import numpy as np
import pandas as pd
import seaborn as sns

# %%
# seaborn datasets also available, originates from here:
# https://github.com/mwaskom/seaborn-data
# these are just csv-files in the background => pandas DataFrames
tips = sns.load_dataset("tips")

# since tips is just a DataFrame, we can add more variables
tips['total_cost'] = tips['total_bill'] + tips['tip']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size  total_cost
# 0         16.99  1.01  Female     No   Sun  Dinner     2       18.00
# 1         10.34  1.66    Male     No   Sun  Dinner     3       12.00
# 2         21.01  3.50    Male     No   Sun  Dinner     3       24.51
# 3         23.68  3.31    Male     No   Sun  Dinner     2       26.99
# 4         24.59  3.61  Female     No   Sun  Dinner     4       28.20
# ..          ...   ...     ...    ...   ...     ...   ...         ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3       34.95
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2       29.18
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2       24.67
# 242       17.82  1.75    Male     No   Sat  Dinner     2       19.57
# 243       18.78  3.00  Female     No  Thur  Dinner     2       21.78
#
# [244 rows x 8 columns]

# %% [markdown]
# ### One of the most powerful features in seaborn -> hue -parameter

# %% [markdown]
# **Hue allows us to compare distributions between nominal categories at the same time.**

# %% [markdown]
# ### Hue is ESPECIALLY powerful in later advanced plots like pair plots, scatter plots, regression plots and box plots!

# %%
# for example with barplot, place a categorical variable in x and hue
# and a continuous variable (like price, cost, tip etc.) into y
# this results into a visualization, where we can inspect the distributions/averages
# upon multiple categories at once
sns.barplot(x="sex", y="total_cost", data=tips, hue="day")
# Out:
# <Axes: xlabel='sex', ylabel='total_cost'>

# %%
# available colors are based on matplotlib:
# https://matplotlib.org/stable/users/explain/colors/colormaps.html

# if you want to alter the default color scheme in seaborn, use palette
# in some plots => cmap
sns.barplot(x="sex", y="total_cost", data=tips, hue="day", palette="magma")
# Out:
# <Axes: xlabel='sex', ylabel='total_cost'>

# %%
# here we can see, lunch is only served on weekdays (Thur/Fri)
# also, Friday has a lot of deviation => variation => both small and big total costs
sns.barplot(x="day", y="total_cost", data=tips, hue="time")
# Out:
# <Axes: xlabel='day', ylabel='total_cost'>

# %%
# a very common strategy with seaborn => ALTERNATE between different variables
# until you find something interesting (insight)
sns.barplot(x="smoker", y="total_cost", data=tips, hue="day")
# Out:
# <Axes: xlabel='smoker', ylabel='total_cost'>

# %%
# remember, if you need to quickly check which columns are avaiable
# use df.head() or df.columns
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  total_cost
# 0       16.99  1.01  Female     No  Sun  Dinner     2       18.00
# 1       10.34  1.66    Male     No  Sun  Dinner     3       12.00
# 2       21.01  3.50    Male     No  Sun  Dinner     3       24.51

# %%
# it seems the biggest groups are present only on Thursday and Sunday (for some reason)
# also on Sunday it seems we don't have any customers coming alone
# values without deviation implies => only few values (or just 1, no deviation)
sns.barplot(x="day", y="total_cost", data=tips, hue="size", palette="coolwarm")

# friday seems to have most deviation in parties of 2 => probably a popular date night in this restaurant?
# Out:
# <Axes: xlabel='day', ylabel='total_cost'>
